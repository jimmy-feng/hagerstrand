# %%
import hagerstrand as hs
from IPython.display import Video

# %%
in_csv = "../../examples/data/world_cities.csv"
out_geojson = "../../examples/data/world_cities.geojson"

# %%
import pandas as pd
pd.read_csv(in_csv).head(5)
# Out:
#           name sov_a3  latitude  longitude  pop_max
# 0        Bombo    UGA    0.5833    32.5333    75000
# 1  Fort Portal    UGA    0.6710    30.2750    42670
# 2      Potenza    ITA   40.6420    15.7990    69060
# 3   Campobasso    ITA   41.5630    14.6560    50762
# 4        Aosta    ITA   45.7370     7.3150    34062

# %% [markdown]
# ### Convert CSV to GeoJSON

# %%
Video(r"../../examples/videos/csv_to_geojson.mp4", height=500, width=750)
# Out:
# <video src="../../examples/videos/csv_to_geojson.mp4" controls  width="750"  height="500">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
y = hs.csv_to_geojson(in_csv)
y
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'id': '0',
#    'type': 'Feature',
#    'properties': {'latitude': 0.5833,
#     'longitude': 32.5333,
#     'name': 'Bombo',
#     'pop_max': 75000,
#     'sov_a3': 'UGA'},
#    'geometry': {'type': 'Point', 'coordinates': (32.5333, 0.5833)},
#    'bbox': (32.5333, 0.5833, 32.5333, 0.5833)},
#   {'id': '1',
#    'type': 'Feature',
#    'properties': {'latitude': 0.671,
#     'longitude': 30.275,
#     'name': 'Fort Portal',
#     'pop_max': 42670,
#     'sov_a3': 'UGA'},
#    'geometry': {'type': 'Point', 'coordinates': (30.275, 0.671)},
#    'bbox': (30.275, 0.671, 30.275, 0.671)},
#   {'id': '2',
#    'type': 'Feature',
#    'properties': {'latitude': 40.642,
#     'longitude': 15.799,
#     'name': 'Potenza',
#     'pop_max': 69060,
#     'sov_a3': 'ITA'},
#    'geometry': {'type': 'Point', 'coordinates': (15.799, 40.642)},
#    'bbox': (15.799, 40.642, 15.799, 40.642)},
#   {'id': '3',
#    'type': 'Feature',
# ...

# %%
y = hs.csv_to_geojson(in_csv, out_geojson)

# %% [markdown]
# ### Convert CSV to ESRI Shapefile

# %%
Video(r"../../examples/videos/csv_to_shp.mp4", height=500, width=750)
# Out:
# <video src="../../examples/videos/csv_to_shp.mp4" controls  width="750"  height="500">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
out_shp = "../../examples/data/world_cities.shp"
z = hs.csv_to_shp(in_csv, out_shp)

# %% [markdown]
# ### Add CSV file of points as marker clusters to an interactive map

# %%
Video(r"../../examples/videos/add_csv_marker_cluster.mp4", height=500, width=750)
# Out:
# <video src="../../examples/videos/add_csv_marker_cluster.mp4" controls  width="750"  height="500">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
Map_hs = hs.Map()
Map_hs.add_points_from_csv(in_csv)
Map_hs
# Out:
# Map(center=[40, -100], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_t…
