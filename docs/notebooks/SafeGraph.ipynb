# %%
# SafeGraph Functions: https://github.com/SafeGraphInc/safegraph_py
#!pip install -q --upgrade git+https://github.com/SafeGraphInc/safegraph_py

# %%
import pandas as pd
pd.set_option('display.max_columns', 500)
import hagerstrand as hs

# %%
stores = pd.read_csv(r"C:\Users\jfeng\Graduate School Coursework Materials\Dissertation\Safegraph_GroceryStores_Patterns_Dec_2020_Feb_2021\February 2021 Activity\core_poi-geometry-patterns-sgpid.csv")
safegraph = pd.read_csv(r"C:\Users\jfeng\Graduate School Coursework Materials\Dissertation\2020_03_SafeGraph_Patterns\2020-03-patterns\core_poi-patterns.csv", index_col=0)

# %%
# Extend data frames with custom class and functions
stores = hs.ExtendedDataFrame(stores)

# Remove duplicate entries
stores = stores.deduplicate(["customer_FullAddress"])

# %%
# 20 Stores without Foot Traffic Information
stores[stores["visitor_home_cbgs"].isnull()]

# %%
# 5 Stores without matching places in SafeGraph
stores[stores["placekey"].isnull()]
# Out:
#            customer_Title              customer_StreetAddress  \
# 28   Magana Mexican Store                   500 W Broadway St
# 29  United Grocery Outlet  Midland Plaza, 148 S Calderwood St
# 30        Green Grocery 2           1822 E Magnolia Ave #7828
# 31         Price Less IGA                 691 Emory Valley Rd
# 32  United Grocery Outlet                                 NaN
#
#                                  customer_FullAddress  customer_NumReviews  \
# 28           500 W Broadway St, Lenoir City, TN 37771                   17
# 29  Midland Plaza, 148 S Calderwood St, Alcoa, TN ...                  253
# 30     1822 E Magnolia Ave #7828, Knoxville, TN 37917                   84
# 31           691 Emory Valley Rd, Oak Ridge, TN 37830                  565
# 32                     227 S Hall Rd, Alcoa, TN 37701                  255
#
#                  customer_PlusCode  \
# 28  QPVQ+88 Lenoir City, Tennessee
# 29        Q26C+F9 Alcoa, Tennessee
# 30    X3HV+HG Knoxville, Tennessee
# 31    2QCC+4X Oak Ridge, Tennessee
# 32        Q28H+2W Alcoa, Tennessee
#
#                                customer_GMAPReviewURL  \
# 28  https://www.google.com/maps/place/Magana+Mexic...
# 29  https://www.google.com/maps/place/United+Groce...
# 30  https://www.google.com/maps/place/Green+Grocer...
# 31  https://www.google.com/maps/place/Price+Less+I...
# 32  https://www.google.com/maps/place/United+Groce...
#
#                                   customer_GMAPPOIURL customer_Category  \
# 28  https://www.google.com/maps/place/Magana+Mexic...           Grocery
# 29  https://www.google.com/maps/place/United+Groce...           Grocery
# 30  https://www.google.com/maps/search/Green+Groce...           Grocery
# 31  https://www.google.com/maps/place/Price+Less+I...           Grocery
# 32  https://www.google.com/maps/place/United+Groce...           Grocery
#
#                        customer_Street customer_City customer_State  \
# 28                   500 W Broadway St   Lenoir City             TN
# 29  Midland Plaza, 148 S Calderwood St         Alcoa             TN
# 30           1822 E Magnolia Ave #7828     Knoxville             TN
# 31                 691 Emory Valley Rd     Oak Ridge             TN
# 32                       227 S Hall Rd         Alcoa             TN
#
#     customer_ZipCode other_match_candidates  number_of_candidate_matches  \
# 28             37771                    NaN                            0
# 29             37701                    NaN                            0
# 30             37917                    NaN                            0
# 31             37830                    NaN                            0
# 32             37701                    NaN                            0
#
#     warnings  is_closed placekey safegraph_place_id parent_placekey  \
# 28       NaN      False      NaN                NaN             NaN
# 29       NaN      False      NaN                NaN             NaN
# 30       NaN      False      NaN                NaN             NaN
# 31       NaN      False      NaN                NaN             NaN
# 32       NaN      False      NaN                NaN             NaN
#
#    parent_safegraph_place_id safegraph_brand_ids location_name brands  \
# 28                       NaN                 NaN           NaN    NaN
# 29                       NaN                 NaN           NaN    NaN
# 30                       NaN                 NaN           NaN    NaN
# 31                       NaN                 NaN           NaN    NaN
# 32                       NaN                 NaN           NaN    NaN
#
#    top_category sub_category  naics_code  latitude  longitude street_address  \
# 28          NaN          NaN         NaN       NaN        NaN            NaN
# 29          NaN          NaN         NaN       NaN        NaN            NaN
# 30          NaN          NaN         NaN       NaN        NaN            NaN
# 31          NaN          NaN         NaN       NaN        NaN            NaN
# 32          NaN          NaN         NaN       NaN        NaN            NaN
#
#    city region  postal_code open_hours category_tags polygon_wkt  \
# 28  NaN    NaN          NaN        NaN           NaN         NaN
# 29  NaN    NaN          NaN        NaN           NaN         NaN
# 30  NaN    NaN          NaN        NaN           NaN         NaN
# 31  NaN    NaN          NaN        NaN           NaN         NaN
# 32  NaN    NaN          NaN        NaN           NaN         NaN
#
#    polygon_class  building_height enclosed  phone_number is_synthetic  \
# 28           NaN              NaN      NaN           NaN          NaN
# 29           NaN              NaN      NaN           NaN          NaN
# 30           NaN              NaN      NaN           NaN          NaN
# 31           NaN              NaN      NaN           NaN          NaN
# 32           NaN              NaN      NaN           NaN          NaN
#
#    includes_parking_lot iso_country_code date_range_start date_range_end  \
# 28                  NaN              NaN              NaN            NaN
# 29                  NaN              NaN              NaN            NaN
# 30                  NaN              NaN              NaN            NaN
# 31                  NaN              NaN              NaN            NaN
# 32                  NaN              NaN              NaN            NaN
#
#     raw_visit_counts  raw_visitor_counts visits_by_day  poi_cbg  \
# 28               NaN                 NaN           NaN      NaN
# 29               NaN                 NaN           NaN      NaN
# 30               NaN                 NaN           NaN      NaN
# 31               NaN                 NaN           NaN      NaN
# 32               NaN                 NaN           NaN      NaN
#
#    visitor_home_cbgs visitor_daytime_cbgs visitor_country_of_origin  \
# 28               NaN                  NaN                       NaN
# 29               NaN                  NaN                       NaN
# 30               NaN                  NaN                       NaN
# 31               NaN                  NaN                       NaN
# 32               NaN                  NaN                       NaN
#
#     distance_from_home  median_dwell bucketed_dwell_times  \
# 28                 NaN           NaN                  NaN
# 29                 NaN           NaN                  NaN
# 30                 NaN           NaN                  NaN
# 31                 NaN           NaN                  NaN
# 32                 NaN           NaN                  NaN
#
#    related_same_day_brand related_same_month_brand popularity_by_hour  \
# 28                    NaN                      NaN                NaN
# 29                    NaN                      NaN                NaN
# 30                    NaN                      NaN                NaN
# 31                    NaN                      NaN                NaN
# 32                    NaN                      NaN                NaN
#
#    popularity_by_day device_type
# 28               NaN         NaN
# 29               NaN         NaN
# 30               NaN         NaN
# 31               NaN         NaN
# 32               NaN         NaN

# %%
stores.to_csv(r"C:\Users\jfeng\Graduate School Coursework Materials\Dissertation\Safegraph_GroceryStores_Patterns_Dec_2020_Feb_2021\February 2021 Activity\core_poi-geometry-patterns-sgpid.csv")

# %%
import json

z = stores["customer_GMAPPOIURL"].to_json(orient='records')
z = json.loads(z)

with open(r"C:\Users\jfeng\Graduate School Coursework Materials\Dissertation\GroceryStoresGMAPURL.json", 'w', encoding='utf-8') as f:
    json.dump(z, f, ensure_ascii=False, indent=4)
    
stores["customer_GMAPPOIURL"].to_json(r"C:\Users\jfeng\Graduate School Coursework Materials\Dissertation\GroceryStoresGMAPURL.json", orient='records', lines=True)

# %%
with open(r"C:\Users\jfeng\Graduate School Coursework Materials\Dissertation\GroceryStoresGMAPURL.json", 'w', encoding='utf-8') as f:
    json.dump(z, f, ensure_ascii=False, indent=4)

# %%
stores["customer_GMAPPOIURL"].to_csv(r"C:\Users\jfeng\Graduate School Coursework Materials\Dissertation\GroceryStoresGMAPURL.txt")

# %%
z = stores["customer_GMAPPOIURL"]
z = z.rename("url")
z = stores["customer_GMAPPOIURL"].to_json(orient='records')
z = json.loads(z)
with open(r"C:\Users\jfeng\Graduate School Coursework Materials\Dissertation\GroceryStoresGMAPURL.json", 'w', encoding='utf-8') as f:
    json.dump(z, f, ensure_ascii=False, indent=4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-5c659df950eb> in <module>
#       2 z = z.rename("url")
#       3 z = stores["customer_GMAPPOIURL"].to_json(orient='records')
# ----> 4 z = json.loads(z)
#       5 with open(r"C:\Users\jfeng\Graduate School Coursework Materials\Dissertation\GroceryStoresGMAPURL.json", 'w', encoding='utf-8') as f:
#       6     json.dump(z, f, ensure_ascii=False, indent=4)
#
# NameError: name 'json' is not defined

# %%
z.items()
# Out:
# dict_items([(0, 'https://www.google.com/maps/search/Food+City%09123+W+Highway+25+70%09Dandridge%09TN%0937725/@36.0171903,-83.4277354,17z'), (1, 'https://www.google.com/maps/place/Save+A+Lot/@35.9985716,-83.8791791,17z/data=!3m1!4b1!4m5!3m4!1s0x885c1692d644ab83:0xde336fef205496d8!8m2!3d35.9985716!4d-83.8769958'), (2, 'https://www.google.com/maps/place/Kroger/@35.9930322,-83.923766,17z/data=!3m2!4b1!5s0x885c1624d5ecf8a3:0xe1022aacbdc79c89!4m5!3m4!1s0x885c163adf9ffd07:0x2063bfd3ad148b89!8m2!3d35.9930322!4d-83.9215827'), (3, 'https://www.google.com/maps/place/Save+A+Lot/@36.3527324,-84.1586451,17z/data=!3m1!4b1!4m5!3m4!1s0x885c51172cc4ce25:0x5410936f6e9dab1c!8m2!3d36.3527281!4d-84.1564564'), (4, 'https://www.google.com/maps/place/Dollar+General/@35.8731138,-83.8320102,12z/data=!4m5!3m4!1s0x885c227ee9c5876b:0x37c3304dcaaaf62f!8m2!3d35.8891437!4d-83.9357622'), (5, 'https://www.google.com/maps/place/Taste+of+Europe/@35.7772267,-83.5444546,17z/data=!4m14!1m8!3m7!1s0x885bfe522987d9e7:0x4fa1544f2e9ada65!2sTaste+of+Europe!8m2!3d35.7772267!4d-83.5444546!14m1!1BCgIgAQ!3m4!1s0x885bfe522987d9e7:0x4fa1544f2e9ada65!8m2!3d35.7772267!4d-83.5444546'), (6, 'https://www.google.com/maps/place/ALDI/@35.8766619,-83.5754871,17z/data=!3m2!4b1!5s0x885bf86051724bad:0xe752c01e605c4483!4m5!3m4!1s0x885bf860543baa29:0xf600daafccbd2da1!8m2!3d35.8766619!4d-83.5733038'), (7, 'https://www.google.com/maps/place/Kroger/@36.0087449,-84.0258336,17z/data=!3m1!4b1!4m5!3m4!1s0x885c3bf3a02efb4d:0x509b7dc995ad16e5!8m2!3d36.0087449!4d-84.0236503'), (8, 'https://www.google.com/maps/search/Kroger%094918+Kingston+Pike/@35.8998092,-83.8203703,17z'), (9, 'https://www.google.com/maps/place/Publix+Super+Market+at+Turkey+Creek/@35.8934043,-84.1723887,17z/data=!3m2!4b1!5s0x885c2e91ff05bd17:0x12b97b0742976171!4m5!3m4!1s0x885c2e8e1da45a71:0xcb94671251452348!8m2!3d35.8934!4d-84.1702'), (10, 'https://www.google.com/maps/place/Publix+Super+Market+at+Valley+Forge+Shopping+Center/@35.8025863,-83.5785367,17z/data=!3m1!4b1!4m5!3m4!1s0x885bff6c0fbd4217:0x88f01cdd61905d43!8m2!3d35.802582!4d-83.576348'), (11, 'https://www.google.com/maps/place/Target/@35.8999897,-84.1539567,17z/data=!3m2!4b1!5s0x885c2efed316f9fd:0x3333a570259e73a0!4m5!3m4!1s0x885c2ef9ae5b9b9b:0x65511e5dc3baf0bf!8m2!3d35.8999854!4d-84.151768'), (12, 'https://www.google.com/maps/place/La+Lupita+Mexican+Store+and+Restaurant+%231/@35.7874506,-84.2729782,17z/data=!3m1!4b1!4m5!3m4!1s0x885c2ab24667aaf9:0xb025731a1d993057!8m2!3d35.7874463!4d-84.2707895'), (13, 'https://www.google.com/maps/place/ALDI/@36.034552,-83.8702679,17z/data=!3m1!4b1!4m5!3m4!1s0x885c15c392a8d69f:0xa67ead9228d2be96!8m2!3d36.034552!4d-83.8680846'), (14, 'https://www.google.com/maps/search/Food+City%0911503+Chapman+Hwy/@35.8771237,-83.7765563,17z'), (15, 'https://www.google.com/maps/place/Food+City/@36.0178811,-84.0492809,17z/data=!3m1!4b1!4m5!3m4!1s0x885c3a27e99e41af:0xadcff3b9db52294e!8m2!3d36.0178811!4d-84.0470976'), (16, 'https://www.google.com/maps/place/Ingles+Markets/@35.9833488,-84.0976499,17z/data=!3m1!4b1!4m5!3m4!1s0x885c3a866d986c47:0xcaabf625c81a7c72!8m2!3d35.9833488!4d-84.0954666'), (17, 'https://www.google.com/maps/place/Food+City/@35.905138,-84.4473965,10z/data=!4m8!1m2!2m1!1sFood+City%09300+Market+Dr!3m4!1s0x885c2ac8a28b623b:0x8f095bf4a2989758!8m2!3d35.8191686!4d-84.2688952'), (18, 'https://www.google.com/maps/place/Ingles+Market/@36.015472,-83.9718233,17z/data=!3m1!4b1!4m5!3m4!1s0x885c3dce1e009101:0xa5115c82d03ca4bc!8m2!3d36.015472!4d-83.96964'), (19, 'https://www.google.com/maps/place/Food+Lion/@35.8017823,-83.9469873,17z/data=!3m1!4b1!4m5!3m4!1s0x885c2032092fdefb:0x3c036bed1dc44a9b!8m2!3d35.801778!4d-83.9447986'), (20, 'https://www.google.com/maps/place/ALDI/@36.00414,-84.249541,17z/data=!3m1!4b1!4m5!3m4!1s0x885c33185911d05d:0xb8e24503c8d9eae0!8m2!3d36.00414!4d-84.2473577'), (21, 'https://www.google.com/maps/place/Food+City/@35.9341026,-84.0030723,17z/data=!3m1!4b1!4m5!3m4!1s0x885c234956550b0f:0x7c86a003b8c20303!8m2!3d35.9340983!4d-84.0008836'),  ...

# %%
od = stores.jsoncol_newdf()
od
# Out:
#            visitor_home_cbgs_key  visitor_home_cbgs_value
# orig_index
# 0                   470890707004                       28
# 0                   470890707002                       22
# 0                   470890708004                       18
# 0                   470890707003                       16
# 0                   470890707001                       14
# ...                          ...                      ...
# 125                 471050603024                        4
# 125                 470575003004                        4
# 125                 470890708001                        4
# 125                 471730401004                        4
# 125                 470631006001                        4
#
# [7768 rows x 2 columns]

# %%
safegraph_unpack = safegraph.jsoncol_merge()
safegraph_unpack
# Out:
#                   placekey                   safegraph_place_id  \
# 0      223-223@8g9-gv4-6tv  sg:126ca050033a40c999ac7f3e39120758
# 1      223-223@8g9-gv4-6tv  sg:126ca050033a40c999ac7f3e39120758
# 2      223-223@8g9-gv4-6tv  sg:126ca050033a40c999ac7f3e39120758
# 3      223-223@8g9-gv4-6tv  sg:126ca050033a40c999ac7f3e39120758
# 4      223-223@8g9-gv4-6tv  sg:126ca050033a40c999ac7f3e39120758
# ...                    ...                                  ...
# 11620  223-222@8g9-m4z-54v  sg:e9dbc7681b3d4260bb00aba2ae24cd0c
# 11621  223-222@8g9-m4z-54v  sg:e9dbc7681b3d4260bb00aba2ae24cd0c
# 11622  223-222@8g9-m4z-54v  sg:e9dbc7681b3d4260bb00aba2ae24cd0c
# 11623  223-222@8g9-m4z-54v  sg:e9dbc7681b3d4260bb00aba2ae24cd0c
# 11624  223-222@8g9-m4z-54v  sg:e9dbc7681b3d4260bb00aba2ae24cd0c
#
#            parent_placekey            parent_safegraph_place_id  \
# 0      223-222@8g9-gv4-6tv  sg:e89e4645e0d34dd096a918cd90266963
# 1      223-222@8g9-gv4-6tv  sg:e89e4645e0d34dd096a918cd90266963
# 2      223-222@8g9-gv4-6tv  sg:e89e4645e0d34dd096a918cd90266963
# 3      223-222@8g9-gv4-6tv  sg:e89e4645e0d34dd096a918cd90266963
# 4      223-222@8g9-gv4-6tv  sg:e89e4645e0d34dd096a918cd90266963
# ...                    ...                                  ...
# 11620  223-223@8g9-m4z-54v  sg:f47888c75cb54ad5be98c5b2a4f3143d
# 11621  223-223@8g9-m4z-54v  sg:f47888c75cb54ad5be98c5b2a4f3143d
# 11622  223-223@8g9-m4z-54v  sg:f47888c75cb54ad5be98c5b2a4f3143d
# 11623  223-223@8g9-m4z-54v  sg:f47888c75cb54ad5be98c5b2a4f3143d
# 11624  223-223@8g9-m4z-54v  sg:f47888c75cb54ad5be98c5b2a4f3143d
#
#                  location_name        safegraph_brand_ids         brands  \
# 0      Bread Box Food Store 45                        NaN            NaN
# 1      Bread Box Food Store 45                        NaN            NaN
# 2      Bread Box Food Store 45                        NaN            NaN
# 3      Bread Box Food Store 45                        NaN            NaN
# 4      Bread Box Food Store 45                        NaN            NaN
# ...                        ...                        ...            ...
# 11620            KenJo Markets  SG_BRAND_52d289c0a104ae10  KenJo Markets
# 11621            KenJo Markets  SG_BRAND_52d289c0a104ae10  KenJo Markets
# 11622            KenJo Markets  SG_BRAND_52d289c0a104ae10  KenJo Markets
# 11623            KenJo Markets  SG_BRAND_52d289c0a104ae10  KenJo Markets
# 11624            KenJo Markets  SG_BRAND_52d289c0a104ae10  KenJo Markets
#
#          top_category                                       sub_category  \
# 0      Grocery Stores  Supermarkets and Other Grocery (except Conveni...
# 1      Grocery Stores  Supermarkets and Other Grocery (except Conveni...
# 2      Grocery Stores  Supermarkets and Other Grocery (except Conveni...
# 3      Grocery Stores  Supermarkets and Other Grocery (except Conveni...
# 4      Grocery Stores  Supermarkets and Other Grocery (except Conveni...
# ...               ...                                                ...
# 11620  Grocery Stores  Supermarkets and Other Grocery (except Conveni...
# 11621  Grocery Stores  Supermarkets and Other Grocery (except Conveni...
# 11622  Grocery Stores  Supermarkets and Other Grocery (except Conveni...
# 11623  Grocery Stores  Supermarkets and Other Grocery (except Conveni...
# 11624  Grocery Stores  Supermarkets and Other Grocery (except Conveni...
#
#        naics_code  ...                               bucketed_dwell_times  \
# 0        445110.0  ...  {"<5":6,"5-10":23,"11-20":4,"21-60":4,"61-120"...
# 1        445110.0  ...  {"<5":6,"5-10":23,"11-20":4,"21-60":4,"61-120"...
# 2        445110.0  ...  {"<5":6,"5-10":23,"11-20":4,"21-60":4,"61-120"...
# 3        445110.0  ...  {"<5":6,"5-10":23,"11-20":4,"21-60":4,"61-120"...
# 4        445110.0  ...  {"<5":6,"5-10":23,"11-20":4,"21-60":4,"61-120"...
# ...           ...  ...                                                ...
# 11620    445110.0  ...  {"<5":16,"5-10":104,"11-20":17,"21-60":14,"61-...
# 11621    445110.0  ...  {"<5":16,"5-10":104,"11-20":17,"21-60":14,"61-...
# 11622    445110.0  ...  {"<5":16,"5-10":104,"11-20":17,"21-60":14,"61-...
# 11623    445110.0  ...  {"<5":16,"5-10":104,"11-20":17,"21-60":14,"61-...
# 11624    445110.0  ...  {"<5":16,"5-10":104,"11-20":17,"21-60":14,"61-...
#
#                                   related_same_day_brand  \
# 0      {"Sam's Club":99,"Shell Oil":99,"Texas Roadhou...
# 1      {"Sam's Club":99,"Shell Oil":99,"Texas Roadhou...
# 2      {"Sam's Club":99,"Shell Oil":99,"Texas Roadhou...
# 3      {"Sam's Club":99,"Shell Oil":99,"Texas Roadhou...
# 4      {"Sam's Club":99,"Shell Oil":99,"Texas Roadhou...
# ...                                                  ...
# 11620  {"Shell Oil":99,"Weigel's":29,"Family Dollar S...
# 11621  {"Shell Oil":99,"Weigel's":29,"Family Dollar S...
# 11622  {"Shell Oil":99,"Weigel's":29,"Family Dollar S...
# 11623  {"Shell Oil":99,"Weigel's":29,"Family Dollar S...
# 11624  {"Shell Oil":99,"Weigel's":29,"Family Dollar S...
#
#                                 related_same_month_brand  \
# 0      {"Shell Oil":94,"Walmart":67,"Weigel's":66,"Mc...
# 1      {"Shell Oil":94,"Walmart":67,"Weigel's":66,"Mc...
# 2      {"Shell Oil":94,"Walmart":67,"Weigel's":66,"Mc...
# 3      {"Shell Oil":94,"Walmart":67,"Weigel's":66,"Mc...
# 4      {"Shell Oil":94,"Walmart":67,"Weigel's":66,"Mc...
# ...                                                  ...
# 11620  {"Shell Oil":94,"Walmart":53,"Dollar General":...
# 11621  {"Shell Oil":94,"Walmart":53,"Dollar General":...
# 11622  {"Shell Oil":94,"Walmart":53,"Dollar General":...
# 11623  {"Shell Oil":94,"Walmart":53,"Dollar General":...
# 11624  {"Shell Oil":94,"Walmart":53,"Dollar General":...
#
#                                       popularity_by_hour  \
# 0      [2,0,0,1,1,1,0,2,3,1,2,1,6,5,3,1,2,4,3,5,2,0,0,0]
# 1      [2,0,0,1,1,1,0,2,3,1,2,1,6,5,3,1,2,4,3,5,2,0,0,0]
# 2      [2,0,0,1,1,1,0,2,3,1,2,1,6,5,3,1,2,4,3,5,2,0,0,0]
# 3      [2,0,0,1,1,1,0,2,3,1,2,1,6,5,3,1,2,4,3,5,2,0,0,0]
# 4      [2,0,0,1,1,1,0,2,3,1,2,1,6,5,3,1,2,4,3,5,2,0,0,0]
# ...                                                  ...
# 11620  [5,5,4,2,1,4,0,4,2,6,5,12,10,17,16,35,26,21,20...
# 11621  [5,5,4,2,1,4,0,4,2,6,5,12,10,17,16,35,26,21,20...
# 11622  [5,5,4,2,1,4,0,4,2,6,5,12,10,17,16,35,26,21,20...
# 11623  [5,5,4,2,1,4,0,4,2,6,5,12,10,17,16,35,26,21,20...
# 11624  [5,5,4,2,1,4,0,4,2,6,5,12,10,17,16,35,26,21,20...
#
#                                        popularity_by_day  \
# 0      {"Monday":6,"Tuesday":5,"Wednesday":3,"Thursda...
# 1      {"Monday":6,"Tuesday":5,"Wednesday":3,"Thursda...
# 2      {"Monday":6,"Tuesday":5,"Wednesday":3,"Thursda...
# 3      {"Monday":6,"Tuesday":5,"Wednesday":3,"Thursda...
# 4      {"Monday":6,"Tuesday":5,"Wednesday":3,"Thursda...
# ...                                                  ...
# 11620  {"Monday":33,"Tuesday":26,"Wednesday":19,"Thur...
# 11621  {"Monday":33,"Tuesday":26,"Wednesday":19,"Thur...
# 11622  {"Monday":33,"Tuesday":26,"Wednesday":19,"Thur...
# 11623  {"Monday":33,"Tuesday":26,"Wednesday":19,"Thur...
# 11624  {"Monday":33,"Tuesday":26,"Wednesday":19,"Thur...
#
#                    device_type       poi_cbg  \
# 0      {"android":14,"ios":19}  4.709301e+11
# 1      {"android":14,"ios":19}  4.709301e+11
# 2      {"android":14,"ios":19}  4.709301e+11
# 3      {"android":14,"ios":19}  4.709301e+11
# 4      {"android":14,"ios":19}  4.709301e+11
# ...                        ...           ...
# 11620  {"android":68,"ios":39}  4.700901e+11
# 11621  {"android":68,"ios":39}  4.700901e+11
# 11622  {"android":68,"ios":39}  4.700901e+11
# 11623  {"android":68,"ios":39}  4.700901e+11
# 11624  {"android":68,"ios":39}  4.700901e+11
#
#                                     visitor_daytime_cbgs  \
# 0      {"470930053012":5,"470930065021":4,"4715508020...
# 1      {"470930053012":5,"470930065021":4,"4715508020...
# 2      {"470930053012":5,"470930065021":4,"4715508020...
# 3      {"470930053012":5,"470930065021":4,"4715508020...
# 4      {"470930053012":5,"470930065021":4,"4715508020...
# ...                                                  ...
# 11620  {"470090107004":10,"470090109004":10,"47009011...
# 11621  {"470090107004":10,"470090109004":10,"47009011...
# 11622  {"470090107004":10,"470090109004":10,"47009011...
# 11623  {"470090107004":10,"470090109004":10,"47009011...
# 11624  {"470090107004":10,"470090109004":10,"47009011...
#
#       visitor_home_cbgs_key  visitor_home_cbgs_value
# 0              470930052013                        4
# 1              470930043002                        4
# 2              470930054022                        4
# 3              170318045062                        4
# 4              470575002003                        4
# ...                     ...                      ...
# 11620          470090109003                        4
# 11621          470090113013                        4
# 11622          371239602004                        4
# 11623          470090109002                        4
# 11624          470090106002                        4
#
# [11625 rows x 43 columns]

# %%
import folium

### ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
### Functions for simple mapping using folium 
### ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

def make_map_plot(df_, 
                  plot_limit=3000, 
                  radius_col=None, 
                  radius_mod=100, 
                  color='black', 
                  fill_color='red', 
                  fill_opacity = 0.2, 
                  pop_up_col=None,
                  tooltip = 'Click for more info.', 
                  zoom_start=4,
                  tiles = 'OpenStreetMap', 
                  map_width = 700,
                  map_height = 400,
                  marker_type= 'circle', 
                  map_plot=None, 
                  verbose=False):
    # Parameters:
      # df_ is a pandas dataframe. It requires a column called "latitude" and a column called "longitude". 
      # radius_col is a column_name or None. If None, every point is given a fixed radius. 
          # Otherwise, the value in the column radius_col is used as the radius. 
      # radius_mod is to scale your radius units to correspond to units on your map.
      # zoom_start is the scale of the map. Larger numbers = higher resolution.
      # color, fill_color, fill_opacity are marker parameters, see others: https://leafletjs.com/reference-1.3.4.html#path 
      # tiles determines the base layer. Open source options include 'OpenStreetMap', 'Stamen Terrain', 'Stamen Toner'
      # map_width and map_height determine the size of the map image (in pixels)
      # marker_type determines what type of marker is being drawn on the map. Options: 'circle' or 'normal'
    
    # check valid inputs
    valid_inputs = {'marker_type' : {'val' : marker_type, 'valids' : ['circle', 'normal']},
                    'tiles' :  {'val' : tiles, 'valids': ['OpenStreetMap', 'Stamen Terrain', 'Stamen Toner', 'Mapbox Bright', 'Mapbox Control Room']},
                    'radius_col' : {'val' : radius_col, 'valids' : [None] + [col for col in df_.columns if pd.api.types.is_numeric_dtype(df_[col])]}}
    for param, param_valid_dict in valid_inputs.items():
        if(param_valid_dict['val'] not in param_valid_dict['valids']):
            raise Exception("Invalid parameter input for '{0}'. Valid options are {1}. input value was '{2}' .".format(param, param_valid_dict['valids'], param_valid_dict['val']))   

    # create basemap
    if(not map_plot):
        map_plot = folium.Map(width=map_width,
                            height=map_height,
                            location=[df_.latitude.mean(), df_.longitude.mean()],
                            tiles=tiles,
                            zoom_start=zoom_start,
                            control_scale = True)

    # add markers
    counter = 0
    for index, row in df_.iterrows():
        counter+=1
        if(marker_type=='circle'):
            add_circle_marker_to_map(map_plot, row, radius_col, radius_mod, color, fill_color, fill_opacity, pop_up_col, tooltip)
        elif(marker_type=='normal'):
            add_marker_to_map(map_plot, row, pop_up_col, tooltip)
        if(counter>plot_limit): break
    if(verbose): print("Plotted {0} locations".format(counter))
    return(map_plot)


def add_marker_to_map(map_plot, row, pop_up_col, tooltip):
    folium.Marker([row.latitude, row.longitude],
                        popup= row[pop_up_col] if pop_up_col else None,
                        tooltip=tooltip if pop_up_col else None,
                   ).add_to(map_plot)
    return(None)


def add_circle_marker_to_map(map_plot, row, radius_col, radius_mod, color, fill_color, fill_opacity, pop_up_col, tooltip):
    folium.CircleMarker([row.latitude, row.longitude],
                        radius= row[radius_col]/radius_mod if radius_col else 2,
                        color = color,
                        fill_color = fill_color,
                        weight=0.5,
                        fill_opacity= fill_opacity,
                        popup= row[pop_up_col] if pop_up_col else None,
                        tooltip=tooltip if pop_up_col else None,
                   ).add_to(map_plot)
    return(None)

# %%
make_map_plot(safegraph, fill_color='red', fill_opacity=1)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_3373f6229ea6443cae0454640bc80048%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20700.0px%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20400.0px%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_3373f6229ea6443cae0454640bc80048%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_3373f6229ea6443cae0454640bc80048%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_3373f6229ea6443cae0454640bc80048%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B35.941868749279536%2C%20-83.9357028242075%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
"""
Construct a new dataframe with the each open and close windows 
separated into individual rows. 

The new dataframe will have the following columns: 
brands, sgpid, day, open_window

note: if a POI has > 1 open window (e.g. open from 10am - 2pm, and 5pm - 10pm), then it will have > 1 row in this dataset

See also:  https://docs.safegraph.com/docs/faqs#section-how-do-i-work-with-the-patterns-columns-that-contain-json-

"""


all_oh_data_list = [] # each open_hour window will be one element in this list
for index, row in safegraph.iterrows():
  for key,value in row['open_hours'].items():
    if(value==[]):
      # note: store is closed all day. 
      this_sgpid_oh_data = [ {'brands': row['brands'], 'safegraph_place_id' : row['safegraph_place_id'], 'day' : key, 'open_window' : []}]    
    else:
      this_sgpid_oh_data = [ {'brands': row['brands'], 'safegraph_place_id' : row['safegraph_place_id'], 'day' : key, 'open_window' : this_range} for this_range in value]  
    all_oh_data_list = all_oh_data_list + this_sgpid_oh_data # concat the lists
 
all_oh_data = pd.DataFrame(all_oh_data_list)

all_oh_data.head()
