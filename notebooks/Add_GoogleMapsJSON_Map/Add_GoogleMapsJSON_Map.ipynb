# %% [markdown]
# ## Import packages

# %%
from hagerstrand.hagerstrand import Map, gmapjson_to_geojson

# %% [markdown]
# ## Instantiate a map

# %%
m = Map()

# %% [markdown]
# ## Add a json of location history as a geojson to the map

# %%
m.add_gmapjson("../../examples/data/LocationHistory.json")

# %%
m
# Out:
# Map(center=[40, -100], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_t…

# %% [markdown]
# ## Convert a json of location history from Google Map to a geojson

# %%
gmapjson_to_geojson("./data/LocationHistory.json")
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.92798239999999, 35.9563627]},
#    'properties': {'timestampMs': '2020-02-05 16:07:59',
#     'latitudeE7': 35.9563627,
#     'longitudeE7': -83.92798239999999,
#     'accuracy': 10,
#     'velocity': 0,
#     'heading': 138,
#     'altitude': 266,
#     'verticalAccuracy': 3}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9280342, 35.9563455]},
#    'properties': {'timestampMs': '2020-02-05 16:09:59',
#     'latitudeE7': 35.9563455,
#     'longitudeE7': -83.9280342,
#     'accuracy': 10,
#     'velocity': 0,
#     'heading': 138,
#     'altitude': 268,
#     'verticalAccuracy': 4}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9280342, 35.9563455]},
#    'properties': {'timestampMs': '2020-02-05 16:12:00',
#     'latitudeE7': 35.9563455,
#     'longitudeE7': -83.9280342,
#     'accuracy': 10,
#     'velocity': 0,
#     'heading': 138,
#     'altitude': 268,
#     'verticalAccuracy': 4}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.9279505, 35.956369099999996]},
#    'properties': {'timestampMs': '2020-02-05 16:13:59',
#     'latitudeE7': 35.956369099999996,
#     'longitudeE7': -83.9279505,
#     'accuracy': 10,
#     'velocity': 0,
#     'heading': 104,
#     'altitude': 268,
#     'verticalAccuracy': 4}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.92775809999999, 35.956503399999995]},
#    'properties': {'timestampMs': '2020-02-05 17:58:08',
#     'latitudeE7': 35.956503399999995,
#     'longitudeE7': -83.92775809999999,
#     'accuracy': 10,
#     'velocity': 0,
#     'altitude': 272,
#     'verticalAccuracy': 6}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.92846589999999, 35.955398699999996]},
#    'properties': {'timestampMs': '2020-02-05 18:39:03',
#     'latitudeE7': 35.955398699999996,
#     'longitudeE7': -83.92846589999999,
#     'accuracy': 10,
#     'velocity': 4,
#     'heading': 245,
#     'altitude': 271,
#     'verticalAccuracy': 16}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.93356949999999, 35.9516418]},
#    'properties': {'timestampMs': '2020-02-05 18:41:40',
#     'latitudeE7': 35.9516418,
#     'longitudeE7': -83.93356949999999,
#     'accuracy': 10,
#     'velocity': 5,
#     'heading': 226,
#     'altitude': 285,
#     'verticalAccuracy': 16}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.9344903, 35.949748899999996]},
#    'properties': {'timestampMs': '2020-02-05 18:44:25',
#     'latitudeE7': 35.949748899999996,
#     'longitudeE7': -83.9344903,
#     'accuracy': 10,
#     'velocity': 1,
#     'heading': 42,
#     'altitude': 289,
#     'verticalAccuracy': 24}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.9342459, 35.948797899999995]},
#    'properties': {'timestampMs': '2020-02-05 18:49:33',
#     'latitudeE7': 35.948797899999995,
#     'longitudeE7': -83.9342459,
#     'accuracy': 65,
#     'altitude': 270,
#     'verticalAccuracy': 10}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.93442429999999, 35.949586599999996]},
#    'properties': {'timestampMs': '2020-02-05 20:06:00',
#     'latitudeE7': 35.949586599999996,
#     'longitudeE7': -83.93442429999999,
#     'accuracy': 10,
#     'velocity': 2,
#     'heading': 319,
#     'altitude': 277,
#     'verticalAccuracy': 16}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.9314608, 35.953383599999995]},
#    'properties': {'timestampMs': '2020-02-05 20:10:37',
#     'latitudeE7': 35.953383599999995,
#     'longitudeE7': -83.9314608,
#     'accuracy': 10,
#     'velocity': 3,
#     'heading': 3,
#     'altitude': 304,
#     'verticalAccuracy': 16}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9286673, 35.9584851]},
#    'properties': {'timestampMs': '2020-02-05 20:13:35',
#     'latitudeE7': 35.9584851,
#     'longitudeE7': -83.9286673,
#     'accuracy': 10,
#     'velocity': 2,
#     'heading': 7,
#     'altitude': 314,
#     'verticalAccuracy': 24}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9250376, 35.9613491]},
#    'properties': {'timestampMs': '2020-02-05 20:15:46',
#     'latitudeE7': 35.9613491,
#     'longitudeE7': -83.9250376,
#     'accuracy': 5,
#     'velocity': 7,
#     'heading': 63,
#     'altitude': 268,
#     'verticalAccuracy': 8}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.91644579999999, 35.9619323]},
#    'properties': {'timestampMs': '2020-02-05 20:19:39',
#     'latitudeE7': 35.9619323,
#     'longitudeE7': -83.91644579999999,
#     'accuracy': 10,
#     'velocity': 3,
#     'heading': 62,
#     'altitude': 322,
#     'verticalAccuracy': 32}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.908902, 35.9635593]},
#    'properties': {'timestampMs': '2020-02-05 20:22:38',
#     'latitudeE7': 35.9635593,
#     'longitudeE7': -83.908902,
#     'accuracy': 10,
#     'velocity': 3,
#     'heading': 63,
#     'altitude': 287,
#     'verticalAccuracy': 24}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9057618, 35.9651]},
#    'properties': {'timestampMs': '2020-02-05 20:25:05',
#     'latitudeE7': 35.9651,
#     'longitudeE7': -83.9057618,
#     'accuracy': 5,
#     'velocity': 1,
#     'heading': 325,
#     'altitude': 273,
#     'verticalAccuracy': 8}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9056463, 35.9653157]},
#    'properties': {'timestampMs': '2020-02-05 21:21:53',
#     'latitudeE7': 35.9653157,
#     'longitudeE7': -83.9056463,
#     'accuracy': 10,
#     'velocity': 0,
#     'altitude': 274,
#     'verticalAccuracy': 12}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9058914, 35.9651466]},
#    'properties': {'timestampMs': '2020-02-06 00:01:06',
#     'latitudeE7': 35.9651466,
#     'longitudeE7': -83.9058914,
#     'accuracy': 10,
#     'velocity': 1,
#     'heading': 349,
#     'altitude': 272,
#     'verticalAccuracy': 6}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.90660009999999, 35.964561599999996]},
#    'properties': {'timestampMs': '2020-02-06 10:32:13',
#     'latitudeE7': 35.964561599999996,
#     'longitudeE7': -83.90660009999999,
#     'accuracy': 10,
#     'velocity': 3,
#     'heading': 128,
#     'altitude': 263,
#     'verticalAccuracy': 8}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.906948, 35.9667664]},
#    'properties': {'timestampMs': '2020-02-06 10:36:22',
#     'latitudeE7': 35.9667664,
#     'longitudeE7': -83.906948,
#     'accuracy': 10,
#     'velocity': 8,
#     'heading': 351,
#     'altitude': 285,
#     'verticalAccuracy': 8}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9128242, 35.9654723]},
#    'properties': {'timestampMs': '2020-02-06 10:38:49',
#     'latitudeE7': 35.9654723,
#     'longitudeE7': -83.9128242,
#     'accuracy': 10,
#     'velocity': 0,
#     'heading': 295,
#     'altitude': 266,
#     'verticalAccuracy': 16}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9168052, 35.9630874]},
#    'properties': {'timestampMs': '2020-02-06 10:41:11',
#     'latitudeE7': 35.9630874,
#     'longitudeE7': -83.9168052,
#     'accuracy': 50,
#     'velocity': 2,
#     'heading': 316,
#     'altitude': 350,
#     'verticalAccuracy': 48}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.91860109999999, 35.9657731]},
#    'properties': {'timestampMs': '2020-02-06 10:44:37',
#     'latitudeE7': 35.9657731,
#     'longitudeE7': -83.91860109999999,
#     'accuracy': 10,
#     'velocity': 1,
#     'altitude': 296,
#     'verticalAccuracy': 12}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.91898839999999, 35.9694146]},
#    'properties': {'timestampMs': '2020-02-06 10:50:12',
#     'latitudeE7': 35.9694146,
#     'longitudeE7': -83.91898839999999,
#     'accuracy': 5,
#     'velocity': 0,
#     'heading': 319,
#     'altitude': 281,
#     'verticalAccuracy': 8}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9184763, 35.9705586]},
#    'properties': {'timestampMs': '2020-02-06 10:52:18',
#     'latitudeE7': 35.9705586,
#     'longitudeE7': -83.9184763,
#     'accuracy': 10,
#     'velocity': 3,
#     'heading': 206,
#     'altitude': 272,
#     'verticalAccuracy': 12}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9194296, 35.9716496]},
#    'properties': {'timestampMs': '2020-02-06 11:01:01',
#     'latitudeE7': 35.9716496,
#     'longitudeE7': -83.9194296,
#     'accuracy': 65,
#     'altitude': 274,
#     'verticalAccuracy': 10}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9179084, 35.9687236]},
#    'properties': {'timestampMs': '2020-02-06 11:51:05',
#     'latitudeE7': 35.9687236,
#     'longitudeE7': -83.9179084,
#     'accuracy': 10,
#     'velocity': 1,
#     'altitude': 313,
#     'verticalAccuracy': 24}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.91944629999999, 35.9673596]},
#    'properties': {'timestampMs': '2020-02-06 11:53:49',
#     'latitudeE7': 35.9673596,
#     'longitudeE7': -83.91944629999999,
#     'accuracy': 10,
#     'velocity': 0,
#     'heading': 146,
#     'altitude': 308,
#     'verticalAccuracy': 12}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9183236, 35.9653364]},
#    'properties': {'timestampMs': '2020-02-06 11:57:21',
#     'latitudeE7': 35.9653364,
#     'longitudeE7': -83.9183236,
#     'accuracy': 10,
#     'velocity': 1,
#     'heading': 176,
#     'altitude': 330,
#     'verticalAccuracy': 24}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.9174561, 35.963893899999995]},
#    'properties': {'timestampMs': '2020-02-06 11:59:40',
#     'latitudeE7': 35.963893899999995,
#     'longitudeE7': -83.9174561,
#     'accuracy': 10,
#     'velocity': 2,
#     'heading': 20,
#     'altitude': 297,
#     'verticalAccuracy': 16}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.9182465, 35.962893699999995]},
#    'properties': {'timestampMs': '2020-02-06 12:07:35',
#     'latitudeE7': 35.962893699999995,
#     'longitudeE7': -83.9182465,
#     'accuracy': 10,
#     'velocity': 0,
#     'heading': 138,
#     'altitude': 282,
#     'verticalAccuracy': 4}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9175376, 35.9611778]},
#    'properties': {'timestampMs': '2020-02-06 12:10:40',
#     'latitudeE7': 35.9611778,
#     'longitudeE7': -83.9175376,
#     'accuracy': 5,
#     'velocity': 0,
#     'heading': 243,
#     'altitude': 275,
#     'verticalAccuracy': 3}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9148878, 35.9612963]},
#    'properties': {'timestampMs': '2020-02-06 12:17:24',
#     'latitudeE7': 35.9612963,
#     'longitudeE7': -83.9148878,
#     'accuracy': 10,
#     'velocity': 11,
#     'heading': 63,
#     'altitude': 284,
#     'verticalAccuracy': 24}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.90578409999999, 35.9654107]},
#    'properties': {'timestampMs': '2020-02-06 12:20:34',
#     'latitudeE7': 35.9654107,
#     'longitudeE7': -83.90578409999999,
#     'accuracy': 10,
#     'velocity': 1,
#     'heading': 40,
#     'altitude': 274,
#     'verticalAccuracy': 8}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9055851, 35.9651139]},
#    'properties': {'timestampMs': '2020-02-06 12:29:49',
#     'latitudeE7': 35.9651139,
#     'longitudeE7': -83.9055851,
#     'accuracy': 10,
#     'velocity': 0,
#     'altitude': 270,
#     'verticalAccuracy': 8}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.9062909, 35.965068599999995]},
#    'properties': {'timestampMs': '2020-02-06 13:16:29',
#     'latitudeE7': 35.965068599999995,
#     'longitudeE7': -83.9062909,
#     'accuracy': 50,
#     'velocity': 3,
#     'heading': 266,
#     'altitude': 285,
#     'verticalAccuracy': 24}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9138052, 35.9618019]},
#    'properties': {'timestampMs': '2020-02-06 13:18:46',
#     'latitudeE7': 35.9618019,
#     'longitudeE7': -83.9138052,
#     'accuracy': 10,
#     'velocity': 7,
#     'heading': 240,
#     'altitude': 262,
#     'verticalAccuracy': 16}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.9194462, 35.964911199999996]},
#    'properties': {'timestampMs': '2020-02-06 13:22:59',
#     'latitudeE7': 35.964911199999996,
#     'longitudeE7': -83.9194462,
#     'accuracy': 65,
#     'altitude': 284,
#     'verticalAccuracy': 10}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9194672, 35.9647116]},
#    'properties': {'timestampMs': '2020-02-06 13:25:27',
#     'latitudeE7': 35.9647116,
#     'longitudeE7': -83.9194672,
#     'accuracy': 65,
#     'altitude': 284,
#     'verticalAccuracy': 10}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.9189696, 35.963749799999995]},
#    'properties': {'timestampMs': '2020-02-06 14:32:59',
#     'latitudeE7': 35.963749799999995,
#     'longitudeE7': -83.9189696,
#     'accuracy': 50,
#     'velocity': 1,
#     'altitude': 280,
#     'verticalAccuracy': 64}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.92594609999999, 35.9586888]},
#    'properties': {'timestampMs': '2020-02-06 14:36:50',
#     'latitudeE7': 35.9586888,
#     'longitudeE7': -83.92594609999999,
#     'accuracy': 65,
#     'altitude': 276,
#     'verticalAccuracy': 10}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.9277254, 35.957590599999996]},
#    'properties': {'timestampMs': '2020-02-06 15:40:10',
#     'latitudeE7': 35.957590599999996,
#     'longitudeE7': -83.9277254,
#     'accuracy': 65,
#     'altitude': 278,
#     'verticalAccuracy': 10}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.92478419999999, 35.9586993]},
#    'properties': {'timestampMs': '2020-02-06 17:03:40',
#     'latitudeE7': 35.9586993,
#     'longitudeE7': -83.92478419999999,
#     'accuracy': 65,
#     'altitude': 265,
#     'verticalAccuracy': 10}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.92232059999999, 35.962465099999996]},
#    'properties': {'timestampMs': '2020-02-06 17:09:31',
#     'latitudeE7': 35.962465099999996,
#     'longitudeE7': -83.92232059999999,
#     'accuracy': 5,
#     'velocity': 5,
#     'heading': 62,
#     'altitude': 295,
#     'verticalAccuracy': 8}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.91832529999999, 35.9648827]},
#    'properties': {'timestampMs': '2020-02-06 17:12:43',
#     'latitudeE7': 35.9648827,
#     'longitudeE7': -83.91832529999999,
#     'accuracy': 10,
#     'velocity': 1,
#     'heading': 36,
#     'altitude': 298,
#     'verticalAccuracy': 12}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9114067, 35.962779]},
#    'properties': {'timestampMs': '2020-02-06 17:17:09',
#     'latitudeE7': 35.962779,
#     'longitudeE7': -83.9114067,
#     'accuracy': 65,
#     'altitude': 271,
#     'verticalAccuracy': 10}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9058553, 35.9652587]},
#    'properties': {'timestampMs': '2020-02-06 17:20:09',
#     'latitudeE7': 35.9652587,
#     'longitudeE7': -83.9058553,
#     'accuracy': 65,
#     'altitude': 272,
#     'verticalAccuracy': 10}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9055064, 35.9650967]},
#    'properties': {'timestampMs': '2020-02-06 17:40:18',
#     'latitudeE7': 35.9650967,
#     'longitudeE7': -83.9055064,
#     'accuracy': 10,
#     'velocity': 2,
#     'heading': 215,
#     'altitude': 266,
#     'verticalAccuracy': 24}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9057708, 35.9650433]},
#    'properties': {'timestampMs': '2020-02-06 17:42:27',
#     'latitudeE7': 35.9650433,
#     'longitudeE7': -83.9057708,
#     'accuracy': 65,
#     'altitude': 270,
#     'verticalAccuracy': 10}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9057849, 35.965151]},
#    'properties': {'timestampMs': '2020-02-06 18:02:04',
#     'latitudeE7': 35.965151,
#     'longitudeE7': -83.9057849,
#     'accuracy': 65,
#     'heading': 172,
#     'altitude': 272,
#     'verticalAccuracy': 10}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.90581449999999, 35.9652098]},
#    'properties': {'timestampMs': '2020-02-07 00:29:27',
#     'latitudeE7': 35.9652098,
#     'longitudeE7': -83.90581449999999,
#     'accuracy': 65,
#     'altitude': 271,
#     'verticalAccuracy': 10}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9085222, 35.9599]},
#    'properties': {'timestampMs': '2020-02-07 07:50:11',
#     'latitudeE7': 35.9599,
#     'longitudeE7': -83.9085222,
#     'accuracy': 109,
#     'heading': 188,
#     'altitude': 265,
#     'verticalAccuracy': 10}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9157585, 35.9608191]},
#    'properties': {'timestampMs': '2020-02-07 07:52:11',
#     'latitudeE7': 35.9608191,
#     'longitudeE7': -83.9157585,
#     'accuracy': 65,
#     'altitude': 272,
#     'verticalAccuracy': 10}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9211832, 35.9628604]},
#    'properties': {'timestampMs': '2020-02-07 07:55:13',
#     'latitudeE7': 35.9628604,
#     'longitudeE7': -83.9211832,
#     'accuracy': 65,
#     'altitude': 278,
#     'verticalAccuracy': 10}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.92593629999999, 35.9610457]},
#    'properties': {'timestampMs': '2020-02-07 07:58:13',
#     'latitudeE7': 35.9610457,
#     'longitudeE7': -83.92593629999999,
#     'accuracy': 10,
#     'velocity': 5,
#     'heading': 242,
#     'altitude': 278,
#     'verticalAccuracy': 12}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9271893, 35.9566328]},
#    'properties': {'timestampMs': '2020-02-07 08:01:14',
#     'latitudeE7': 35.9566328,
#     'longitudeE7': -83.9271893,
#     'accuracy': 10,
#     'velocity': 2,
#     'heading': 140,
#     'altitude': 276,
#     'verticalAccuracy': 12}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9276584, 35.9564466]},
#    'properties': {'timestampMs': '2020-02-07 09:08:53',
#     'latitudeE7': 35.9564466,
#     'longitudeE7': -83.9276584,
#     'accuracy': 65,
#     'altitude': 272,
#     'verticalAccuracy': 10}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9277208, 35.9564958]},
#    'properties': {'timestampMs': '2020-02-07 11:57:00',
#     'latitudeE7': 35.9564958,
#     'longitudeE7': -83.9277208,
#     'accuracy': 65,
#     'altitude': 272,
#     'verticalAccuracy': 10}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.927762, 35.9564208]},
#    'properties': {'timestampMs': '2020-02-07 12:04:35',
#     'latitudeE7': 35.9564208,
#     'longitudeE7': -83.927762,
#     'accuracy': 65,
#     'altitude': 271,
#     'verticalAccuracy': 10}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9278015, 35.9564449]},
#    'properties': {'timestampMs': '2020-02-07 12:13:38',
#     'latitudeE7': 35.9564449,
#     'longitudeE7': -83.9278015,
#     'accuracy': 65,
#     'altitude': 271,
#     'verticalAccuracy': 10}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9278617, 35.9564573]},
#    'properties': {'timestampMs': '2020-02-07 12:21:58',
#     'latitudeE7': 35.9564573,
#     'longitudeE7': -83.9278617,
#     'accuracy': 50,
#     'velocity': 0,
#     'altitude': 275,
#     'verticalAccuracy': 96}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.92901789999999, 35.9548237]},
#    'properties': {'timestampMs': '2020-02-07 19:33:21',
#     'latitudeE7': 35.9548237,
#     'longitudeE7': -83.92901789999999,
#     'accuracy': 65,
#     'altitude': 281,
#     'verticalAccuracy': 10}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.93354939999999, 35.9521715]},
#    'properties': {'timestampMs': '2020-02-07 19:35:44',
#     'latitudeE7': 35.9521715,
#     'longitudeE7': -83.93354939999999,
#     'accuracy': 30,
#     'velocity': 5,
#     'heading': 223,
#     'altitude': 287,
#     'verticalAccuracy': 48}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9345902, 35.9496636]},
#    'properties': {'timestampMs': '2020-02-07 19:38:14',
#     'latitudeE7': 35.9496636,
#     'longitudeE7': -83.9345902,
#     'accuracy': 108,
#     'altitude': 276,
#     'verticalAccuracy': 10}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9338918, 35.9486096]},
#    'properties': {'timestampMs': '2020-02-07 19:51:47',
#     'latitudeE7': 35.9486096,
#     'longitudeE7': -83.9338918,
#     'accuracy': 65,
#     'altitude': 268,
#     'verticalAccuracy': 10}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9343323, 35.9493329]},
#    'properties': {'timestampMs': '2020-02-07 19:53:49',
#     'latitudeE7': 35.9493329,
#     'longitudeE7': -83.9343323,
#     'accuracy': 65,
#     'altitude': 274,
#     'verticalAccuracy': 10}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.93428949999999, 35.9491061]},
#    'properties': {'timestampMs': '2020-02-07 20:06:50',
#     'latitudeE7': 35.9491061,
#     'longitudeE7': -83.93428949999999,
#     'accuracy': 65,
#     'altitude': 271,
#     'verticalAccuracy': 10}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9345316, 35.9499425]},
#    'properties': {'timestampMs': '2020-02-07 20:58:25',
#     'latitudeE7': 35.9499425,
#     'longitudeE7': -83.9345316,
#     'accuracy': 10,
#     'velocity': 0,
#     'altitude': 275,
#     'verticalAccuracy': 12}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9290891, 35.9551905]},
#    'properties': {'timestampMs': '2020-02-07 21:02:26',
#     'latitudeE7': 35.9551905,
#     'longitudeE7': -83.9290891,
#     'accuracy': 65,
#     'altitude': 281,
#     'verticalAccuracy': 10}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9284854, 35.960097]},
#    'properties': {'timestampMs': '2020-02-07 21:05:18',
#     'latitudeE7': 35.960097,
#     'longitudeE7': -83.9284854,
#     'accuracy': 10,
#     'velocity': 3,
#     'heading': 68,
#     'altitude': 260,
#     'verticalAccuracy': 48}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9202205, 35.9618257]},
#    'properties': {'timestampMs': '2020-02-07 21:08:20',
#     'latitudeE7': 35.9618257,
#     'longitudeE7': -83.9202205,
#     'accuracy': 50,
#     'velocity': 3,
#     'heading': 155,
#     'altitude': 282,
#     'verticalAccuracy': 48}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9127001, 35.9623333]},
#    'properties': {'timestampMs': '2020-02-07 21:11:24',
#     'latitudeE7': 35.9623333,
#     'longitudeE7': -83.9127001,
#     'accuracy': 50,
#     'velocity': 3,
#     'heading': 78,
#     'altitude': 278,
#     'verticalAccuracy': 128}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9062043, 35.9656267]},
#    'properties': {'timestampMs': '2020-02-07 21:14:12',
#     'latitudeE7': 35.9656267,
#     'longitudeE7': -83.9062043,
#     'accuracy': 65,
#     'altitude': 277,
#     'verticalAccuracy': 10}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9058543, 35.9654299]},
#    'properties': {'timestampMs': '2020-02-07 23:22:04',
#     'latitudeE7': 35.9654299,
#     'longitudeE7': -83.9058543,
#     'accuracy': 65,
#     'altitude': 273,
#     'verticalAccuracy': 10}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9058484, 35.965435]},
#    'properties': {'timestampMs': '2020-02-08 10:51:21',
#     'latitudeE7': 35.965435,
#     'longitudeE7': -83.9058484,
#     'accuracy': 30,
#     'velocity': 0,
#     'altitude': 275,
#     'verticalAccuracy': 3}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.9058585, 35.965152499999995]},
#    'properties': {'timestampMs': '2020-02-08 12:10:23',
#     'latitudeE7': 35.965152499999995,
#     'longitudeE7': -83.9058585,
#     'accuracy': 10,
#     'velocity': 1,
#     'heading': 19,
#     'altitude': 272,
#     'verticalAccuracy': 4}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.9058328, 35.965204299999996]},
#    'properties': {'timestampMs': '2020-02-08 12:12:19',
#     'latitudeE7': 35.965204299999996,
#     'longitudeE7': -83.9058328,
#     'accuracy': 10,
#     'velocity': 0,
#     'heading': 71,
#     'altitude': 277,
#     'verticalAccuracy': 3}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.905819, 35.9652111]},
#    'properties': {'timestampMs': '2020-02-08 12:14:18',
#     'latitudeE7': 35.9652111,
#     'longitudeE7': -83.905819,
#     'accuracy': 10,
#     'velocity': 0,
#     'altitude': 276,
#     'verticalAccuracy': 3}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.9079569, 35.963943199999996]},
#    'properties': {'timestampMs': '2020-02-08 12:34:16',
#     'latitudeE7': 35.963943199999996,
#     'longitudeE7': -83.9079569,
#     'accuracy': 5,
#     'velocity': 5,
#     'heading': 247,
#     'altitude': 291,
#     'verticalAccuracy': 8}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.9160504, 35.961521399999995]},
#    'properties': {'timestampMs': '2020-02-08 12:36:38',
#     'latitudeE7': 35.961521399999995,
#     'longitudeE7': -83.9160504,
#     'accuracy': 10,
#     'velocity': 0,
#     'altitude': 273,
#     'verticalAccuracy': 6}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9216738, 35.962772]},
#    'properties': {'timestampMs': '2020-02-08 12:39:38',
#     'latitudeE7': 35.962772,
#     'longitudeE7': -83.9216738,
#     'accuracy': 10,
#     'velocity': 9,
#     'heading': 247,
#     'altitude': 275,
#     'verticalAccuracy': 4}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9289928, 35.9590935]},
#    'properties': {'timestampMs': '2020-02-08 12:42:39',
#     'latitudeE7': 35.9590935,
#     'longitudeE7': -83.9289928,
#     'accuracy': 10,
#     'velocity': 4,
#     'heading': 169,
#     'altitude': 283,
#     'verticalAccuracy': 24}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.93071049999999, 35.9536239]},
#    'properties': {'timestampMs': '2020-02-08 12:45:39',
#     'latitudeE7': 35.9536239,
#     'longitudeE7': -83.93071049999999,
#     'accuracy': 10,
#     'velocity': 3,
#     'heading': 230,
#     'altitude': 290,
#     'verticalAccuracy': 4}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.93437279999999, 35.9493833]},
#    'properties': {'timestampMs': '2020-02-08 12:48:55',
#     'latitudeE7': 35.9493833,
#     'longitudeE7': -83.93437279999999,
#     'accuracy': 30,
#     'velocity': 0,
#     'heading': 59,
#     'altitude': 276,
#     'verticalAccuracy': 4}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.934294, 35.9490605]},
#    'properties': {'timestampMs': '2020-02-08 13:00:17',
#     'latitudeE7': 35.9490605,
#     'longitudeE7': -83.934294,
#     'accuracy': 65,
#     'heading': 350,
#     'altitude': 271,
#     'verticalAccuracy': 10}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9344715, 35.9497038]},
#    'properties': {'timestampMs': '2020-02-08 13:49:53',
#     'latitudeE7': 35.9497038,
#     'longitudeE7': -83.9344715,
#     'accuracy': 10,
#     'altitude': 284,
#     'verticalAccuracy': 12}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9328235, 35.9524632]},
#    'properties': {'timestampMs': '2020-02-08 13:52:05',
#     'latitudeE7': 35.9524632,
#     'longitudeE7': -83.9328235,
#     'accuracy': 5,
#     'velocity': 3,
#     'heading': 49,
#     'altitude': 285,
#     'verticalAccuracy': 4}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.929981, 35.9566782]},
#    'properties': {'timestampMs': '2020-02-08 13:54:28',
#     'latitudeE7': 35.9566782,
#     'longitudeE7': -83.929981,
#     'accuracy': 10,
#     'velocity': 5,
#     'heading': 337,
#     'altitude': 285,
#     'verticalAccuracy': 4}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.92094469999999, 35.9628571]},
#    'properties': {'timestampMs': '2020-02-08 13:58:36',
#     'latitudeE7': 35.9628571,
#     'longitudeE7': -83.92094469999999,
#     'accuracy': 10,
#     'velocity': 3,
#     'heading': 153,
#     'altitude': 278,
#     'verticalAccuracy': 4}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.91509839999999, 35.9614605]},
#    'properties': {'timestampMs': '2020-02-08 14:01:21',
#     'latitudeE7': 35.9614605,
#     'longitudeE7': -83.91509839999999,
#     'accuracy': 10,
#     'velocity': 10,
#     'heading': 82,
#     'altitude': 272,
#     'verticalAccuracy': 6}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.90619749999999, 35.9649141]},
#    'properties': {'timestampMs': '2020-02-08 14:04:30',
#     'latitudeE7': 35.9649141,
#     'longitudeE7': -83.90619749999999,
#     'accuracy': 10,
#     'altitude': 273,
#     'verticalAccuracy': 8}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9097826, 35.9630422]},
#    'properties': {'timestampMs': '2020-02-08 14:28:33',
#     'latitudeE7': 35.9630422,
#     'longitudeE7': -83.9097826,
#     'accuracy': 5,
#     'velocity': 6,
#     'heading': 241,
#     'altitude': 278,
#     'verticalAccuracy': 8}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9184765, 35.9633823]},
#    'properties': {'timestampMs': '2020-02-08 14:31:44',
#     'latitudeE7': 35.9633823,
#     'longitudeE7': -83.9184765,
#     'accuracy': 10,
#     'velocity': 3,
#     'heading': 331,
#     'altitude': 283,
#     'verticalAccuracy': 12}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.9195356, 35.964830899999995]},
#    'properties': {'timestampMs': '2020-02-08 14:39:48',
#     'latitudeE7': 35.964830899999995,
#     'longitudeE7': -83.9195356,
#     'accuracy': 25,
#     'velocity': 0,
#     'heading': 60,
#     'altitude': 284,
#     'verticalAccuracy': 4}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9214318, 35.9628266]},
#    'properties': {'timestampMs': '2020-02-08 14:48:08',
#     'latitudeE7': 35.9628266,
#     'longitudeE7': -83.9214318,
#     'accuracy': 10,
#     'velocity': 1,
#     'heading': 238,
#     'altitude': 276,
#     'verticalAccuracy': 4}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.92260329999999, 35.9622329]},
#    'properties': {'timestampMs': '2020-02-08 14:50:29',
#     'latitudeE7': 35.9622329,
#     'longitudeE7': -83.92260329999999,
#     'accuracy': 10,
#     'velocity': 0,
#     'heading': 42,
#     'altitude': 270,
#     'verticalAccuracy': 4}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9254746, 35.9619482]},
#    'properties': {'timestampMs': '2020-02-08 14:55:03',
#     'latitudeE7': 35.9619482,
#     'longitudeE7': -83.9254746,
#     'accuracy': 10,
#     'velocity': 1,
#     'heading': 350,
#     'altitude': 276,
#     'verticalAccuracy': 6}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9249593, 35.9621113]},
#    'properties': {'timestampMs': '2020-02-08 16:22:43',
#     'latitudeE7': 35.9621113,
#     'longitudeE7': -83.9249593,
#     'accuracy': 10,
#     'velocity': 1,
#     'heading': 288,
#     'altitude': 266,
#     'verticalAccuracy': 16}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9251603, 35.9616156]},
#    'properties': {'timestampMs': '2020-02-08 16:25:43',
#     'latitudeE7': 35.9616156,
#     'longitudeE7': -83.9251603,
#     'accuracy': 10,
#     'velocity': 0,
#     'heading': 88,
#     'altitude': 269,
#     'verticalAccuracy': 6}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.92302509999999, 35.962268699999996]},
#    'properties': {'timestampMs': '2020-02-08 16:28:45',
#     'latitudeE7': 35.962268699999996,
#     'longitudeE7': -83.92302509999999,
#     'accuracy': 10,
#     'velocity': 1,
#     'heading': 32,
#     'altitude': 273,
#     'verticalAccuracy': 8}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9217354, 35.9627456]},
#    'properties': {'timestampMs': '2020-02-08 16:31:44',
#     'latitudeE7': 35.9627456,
#     'longitudeE7': -83.9217354,
#     'accuracy': 10,
#     'velocity': 1,
#     'heading': 46,
#     'altitude': 274,
#     'verticalAccuracy': 6}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9198146, 35.9635476]},
#    'properties': {'timestampMs': '2020-02-08 16:34:47',
#     'latitudeE7': 35.9635476,
#     'longitudeE7': -83.9198146,
#     'accuracy': 10,
#     'velocity': 1,
#     'heading': 100,
#     'altitude': 281,
#     'verticalAccuracy': 4}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.91933449999999, 35.9646255]},
#    'properties': {'timestampMs': '2020-02-08 16:37:45',
#     'latitudeE7': 35.9646255,
#     'longitudeE7': -83.91933449999999,
#     'accuracy': 10,
#     'velocity': 2,
#     'heading': 346,
#     'altitude': 287,
#     'verticalAccuracy': 12}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9186867, 35.9639582]},
#    'properties': {'timestampMs': '2020-02-08 16:40:47',
#     'latitudeE7': 35.9639582,
#     'longitudeE7': -83.9186867,
#     'accuracy': 10,
#     'velocity': 0,
#     'heading': 308,
#     'altitude': 284,
#     'verticalAccuracy': 4}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.91916719999999, 35.964374299999996]},
#    'properties': {'timestampMs': '2020-02-08 16:44:06',
#     'latitudeE7': 35.964374299999996,
#     'longitudeE7': -83.91916719999999,
#     'accuracy': 10,
#     'velocity': 0,
#     'heading': 298,
#     'altitude': 283,
#     'verticalAccuracy': 4}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.91756989999999, 35.9639698]},
#    'properties': {'timestampMs': '2020-02-08 16:47:51',
#     'latitudeE7': 35.9639698,
#     'longitudeE7': -83.91756989999999,
#     'accuracy': 10,
#     'velocity': 0,
#     'altitude': 287,
#     'verticalAccuracy': 4}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.91323729999999, 35.962196399999996]},
#    'properties': {'timestampMs': '2020-02-08 16:50:19',
#     'latitudeE7': 35.962196399999996,
#     'longitudeE7': -83.91323729999999,
#     'accuracy': 10,
#     'velocity': 5,
#     'heading': 61,
#     'altitude': 255,
#     'verticalAccuracy': 6}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9058845, 35.9650207]},
#    'properties': {'timestampMs': '2020-02-08 16:53:06',
#     'latitudeE7': 35.9650207,
#     'longitudeE7': -83.9058845,
#     'accuracy': 10,
#     'velocity': 1,
#     'heading': 55,
#     'altitude': 272,
#     'verticalAccuracy': 6}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.9063508, 35.965435299999996]},
#    'properties': {'timestampMs': '2020-02-08 19:28:27',
#     'latitudeE7': 35.965435299999996,
#     'longitudeE7': -83.9063508,
#     'accuracy': 10,
#     'velocity': 1,
#     'heading': 324,
#     'altitude': 277,
#     'verticalAccuracy': 6}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9057378, 35.9650029]},
#    'properties': {'timestampMs': '2020-02-08 20:07:38',
#     'latitudeE7': 35.9650029,
#     'longitudeE7': -83.9057378,
#     'accuracy': 10,
#     'velocity': 0,
#     'heading': 311,
#     'altitude': 269,
#     'verticalAccuracy': 6}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.90578239999999, 35.965178]},
#    'properties': {'timestampMs': '2020-02-08 21:45:01',
#     'latitudeE7': 35.965178,
#     'longitudeE7': -83.90578239999999,
#     'accuracy': 10,
#     'velocity': 0,
#     'altitude': 273,
#     'verticalAccuracy': 6}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9154928, 35.9611412]},
#    'properties': {'timestampMs': '2020-02-09 18:17:13',
#     'latitudeE7': 35.9611412,
#     'longitudeE7': -83.9154928,
#     'accuracy': 10,
#     'velocity': 4,
#     'heading': 268,
#     'altitude': 274,
#     'verticalAccuracy': 4}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9189748, 35.9636541]},
#    'properties': {'timestampMs': '2020-02-09 18:19:38',
#     'latitudeE7': 35.9636541,
#     'longitudeE7': -83.9189748,
#     'accuracy': 10,
#     'velocity': 0,
#     'heading': 238,
#     'altitude': 282,
#     'verticalAccuracy': 4}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.92598559999999, 35.9609257]},
#    'properties': {'timestampMs': '2020-02-09 18:23:41',
#     'latitudeE7': 35.9609257,
#     'longitudeE7': -83.92598559999999,
#     'accuracy': 10,
#     'velocity': 4,
#     'heading': 235,
#     'altitude': 273,
#     'verticalAccuracy': 4}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9295551, 35.9574962]},
#    'properties': {'timestampMs': '2020-02-09 18:26:42',
#     'latitudeE7': 35.9574962,
#     'longitudeE7': -83.9295551,
#     'accuracy': 10,
#     'velocity': 2,
#     'heading': 253,
#     'altitude': 279,
#     'verticalAccuracy': 12}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9302259, 35.9540449]},
#    'properties': {'timestampMs': '2020-02-09 18:29:07',
#     'latitudeE7': 35.9540449,
#     'longitudeE7': -83.9302259,
#     'accuracy': 10,
#     'velocity': 2,
#     'heading': 213,
#     'altitude': 289,
#     'verticalAccuracy': 4}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9343639, 35.9496081]},
#    'properties': {'timestampMs': '2020-02-09 18:32:48',
#     'latitudeE7': 35.9496081,
#     'longitudeE7': -83.9343639,
#     'accuracy': 10,
#     'velocity': 1,
#     'altitude': 276,
#     'verticalAccuracy': 16}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9343437, 35.9489525]},
#    'properties': {'timestampMs': '2020-02-09 18:54:03',
#     'latitudeE7': 35.9489525,
#     'longitudeE7': -83.9343437,
#     'accuracy': 50,
#     'velocity': 0,
#     'altitude': 273,
#     'verticalAccuracy': 8}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9344728, 35.9498141]},
#    'properties': {'timestampMs': '2020-02-09 19:50:33',
#     'latitudeE7': 35.9498141,
#     'longitudeE7': -83.9344728,
#     'accuracy': 5,
#     'altitude': 280,
#     'verticalAccuracy': 4}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9371851, 35.9490894]},
#    'properties': {'timestampMs': '2020-02-09 19:52:46',
#     'latitudeE7': 35.9490894,
#     'longitudeE7': -83.9371851,
#     'accuracy': 10,
#     'velocity': 6,
#     'heading': 232,
#     'altitude': 259,
#     'verticalAccuracy': 12}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9393803, 35.9503736]},
#    'properties': {'timestampMs': '2020-02-09 19:55:38',
#     'latitudeE7': 35.9503736,
#     'longitudeE7': -83.9393803,
#     'accuracy': 10,
#     'velocity': 3,
#     'heading': 303,
#     'altitude': 256,
#     'verticalAccuracy': 6}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.93945099999999, 35.9500952]},
#    'properties': {'timestampMs': '2020-02-09 19:59:09',
#     'latitudeE7': 35.9500952,
#     'longitudeE7': -83.93945099999999,
#     'accuracy': 65,
#     'altitude': 260,
#     'verticalAccuracy': 10}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.9362151, 35.950023699999996]},
#    'properties': {'timestampMs': '2020-02-09 20:24:28',
#     'latitudeE7': 35.950023699999996,
#     'longitudeE7': -83.9362151,
#     'accuracy': 10,
#     'velocity': 4,
#     'heading': 45,
#     'altitude': 276,
#     'verticalAccuracy': 6}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9290339, 35.9551316]},
#    'properties': {'timestampMs': '2020-02-09 20:28:34',
#     'latitudeE7': 35.9551316,
#     'longitudeE7': -83.9290339,
#     'accuracy': 10,
#     'velocity': 4,
#     'heading': 352,
#     'altitude': 289,
#     'verticalAccuracy': 16}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.92815019999999, 35.9601481]},
#    'properties': {'timestampMs': '2020-02-09 20:31:12',
#     'latitudeE7': 35.9601481,
#     'longitudeE7': -83.92815019999999,
#     'accuracy': 5,
#     'velocity': 4,
#     'heading': 50,
#     'altitude': 280,
#     'verticalAccuracy': 12}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9211682, 35.9629383]},
#    'properties': {'timestampMs': '2020-02-09 20:33:16',
#     'latitudeE7': 35.9629383,
#     'longitudeE7': -83.9211682,
#     'accuracy': 10,
#     'velocity': 4,
#     'heading': 60,
#     'altitude': 276,
#     'verticalAccuracy': 16}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9149101, 35.9613017]},
#    'properties': {'timestampMs': '2020-02-09 20:36:17',
#     'latitudeE7': 35.9613017,
#     'longitudeE7': -83.9149101,
#     'accuracy': 10,
#     'velocity': 8,
#     'heading': 63,
#     'altitude': 268,
#     'verticalAccuracy': 8}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9075306, 35.9642872]},
#    'properties': {'timestampMs': '2020-02-09 20:39:06',
#     'latitudeE7': 35.9642872,
#     'longitudeE7': -83.9075306,
#     'accuracy': 10,
#     'velocity': 4,
#     'heading': 60,
#     'altitude': 282,
#     'verticalAccuracy': 4}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.90597819999999, 35.9650213]},
#    'properties': {'timestampMs': '2020-02-09 20:42:20',
#     'latitudeE7': 35.9650213,
#     'longitudeE7': -83.90597819999999,
#     'accuracy': 10,
#     'velocity': 0,
#     'altitude': 273,
#     'verticalAccuracy': 4}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9060234, 35.9651237]},
#    'properties': {'timestampMs': '2020-02-10 12:12:34',
#     'latitudeE7': 35.9651237,
#     'longitudeE7': -83.9060234,
#     'accuracy': 30,
#     'velocity': 0,
#     'altitude': 273,
#     'verticalAccuracy': 4}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9107854, 35.9626193]},
#    'properties': {'timestampMs': '2020-02-10 12:14:50',
#     'latitudeE7': 35.9626193,
#     'longitudeE7': -83.9107854,
#     'accuracy': 10,
#     'velocity': 8,
#     'heading': 237,
#     'altitude': 291,
#     'verticalAccuracy': 16}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9226652, 35.9624576]},
#    'properties': {'timestampMs': '2020-02-10 12:19:45',
#     'latitudeE7': 35.9624576,
#     'longitudeE7': -83.9226652,
#     'accuracy': 10,
#     'velocity': 6,
#     'heading': 251,
#     'altitude': 284,
#     'verticalAccuracy': 12}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9276079, 35.9580009]},
#    'properties': {'timestampMs': '2020-02-10 12:23:02',
#     'latitudeE7': 35.9580009,
#     'longitudeE7': -83.9276079,
#     'accuracy': 10,
#     'velocity': 2,
#     'heading': 200,
#     'altitude': 286,
#     'verticalAccuracy': 16}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9278973, 35.9563997]},
#    'properties': {'timestampMs': '2020-02-10 12:27:59',
#     'latitudeE7': 35.9563997,
#     'longitudeE7': -83.9278973,
#     'accuracy': 10,
#     'velocity': 0,
#     'heading': 198,
#     'altitude': 290,
#     'verticalAccuracy': 32}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9271486, 35.9564667]},
#    'properties': {'timestampMs': '2020-02-10 14:07:27',
#     'latitudeE7': 35.9564667,
#     'longitudeE7': -83.9271486,
#     'accuracy': 5,
#     'velocity': 1,
#     'heading': 217,
#     'altitude': 276,
#     'verticalAccuracy': 4}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9281214, 35.9558199]},
#    'properties': {'timestampMs': '2020-02-10 15:07:26',
#     'latitudeE7': 35.9558199,
#     'longitudeE7': -83.9281214,
#     'accuracy': 5,
#     'velocity': 1,
#     'heading': 67,
#     'altitude': 277,
#     'verticalAccuracy': 8}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9277522, 35.9574474]},
#    'properties': {'timestampMs': '2020-02-10 19:04:15',
#     'latitudeE7': 35.9574474,
#     'longitudeE7': -83.9277522,
#     'accuracy': 65,
#     'altitude': 278,
#     'verticalAccuracy': 10}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.923901, 35.961751299999996]},
#    'properties': {'timestampMs': '2020-02-10 19:07:11',
#     'latitudeE7': 35.961751299999996,
#     'longitudeE7': -83.923901,
#     'accuracy': 10,
#     'velocity': 6,
#     'heading': 73,
#     'altitude': 276,
#     'verticalAccuracy': 16}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9180894, 35.9648507]},
#    'properties': {'timestampMs': '2020-02-10 19:10:15',
#     'latitudeE7': 35.9648507,
#     'longitudeE7': -83.9180894,
#     'accuracy': 10,
#     'velocity': 5,
#     'heading': 130,
#     'altitude': 279,
#     'verticalAccuracy': 32}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.910196, 35.962810399999995]},
#    'properties': {'timestampMs': '2020-02-10 19:13:52',
#     'latitudeE7': 35.962810399999995,
#     'longitudeE7': -83.910196,
#     'accuracy': 10,
#     'velocity': 8,
#     'heading': 11,
#     'altitude': 280,
#     'verticalAccuracy': 24}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9057577, 35.9649542]},
#    'properties': {'timestampMs': '2020-02-10 19:16:57',
#     'latitudeE7': 35.9649542,
#     'longitudeE7': -83.9057577,
#     'accuracy': 10,
#     'velocity': 1,
#     'heading': 150,
#     'altitude': 270,
#     'verticalAccuracy': 24}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.9058069, 35.965646899999996]},
#    'properties': {'timestampMs': '2020-02-10 21:25:22',
#     'latitudeE7': 35.965646899999996,
#     'longitudeE7': -83.9058069,
#     'accuracy': 10,
#     'velocity': 0,
#     'heading': 283,
#     'altitude': 291,
#     'verticalAccuracy': 24}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9058307, 35.9652236]},
#    'properties': {'timestampMs': '2020-02-10 22:05:06',
#     'latitudeE7': 35.9652236,
#     'longitudeE7': -83.9058307,
#     'accuracy': 10,
#     'velocity': 0,
#     'heading': 184,
#     'altitude': 275,
#     'verticalAccuracy': 12}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.91492699999999, 35.9611851]},
#    'properties': {'timestampMs': '2020-02-11 14:10:29',
#     'latitudeE7': 35.9611851,
#     'longitudeE7': -83.91492699999999,
#     'accuracy': 10,
#     'velocity': 3,
#     'heading': 304,
#     'altitude': 273,
#     'verticalAccuracy': 24}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9194, 35.9628764]},
#    'properties': {'timestampMs': '2020-02-11 14:13:16',
#     'latitudeE7': 35.9628764,
#     'longitudeE7': -83.9194,
#     'accuracy': 10,
#     'velocity': 3,
#     'heading': 255,
#     'altitude': 296,
#     'verticalAccuracy': 12}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.926204, 35.960990699999996]},
#    'properties': {'timestampMs': '2020-02-11 14:15:23',
#     'latitudeE7': 35.960990699999996,
#     'longitudeE7': -83.926204,
#     'accuracy': 10,
#     'velocity': 2,
#     'heading': 219,
#     'altitude': 291,
#     'verticalAccuracy': 24}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9270165, 35.9565225]},
#    'properties': {'timestampMs': '2020-02-11 14:18:25',
#     'latitudeE7': 35.9565225,
#     'longitudeE7': -83.9270165,
#     'accuracy': 10,
#     'velocity': 1,
#     'heading': 150,
#     'altitude': 288,
#     'verticalAccuracy': 24}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.93214429999999, 35.9528781]},
#    'properties': {'timestampMs': '2020-02-11 14:20:44',
#     'latitudeE7': 35.9528781,
#     'longitudeE7': -83.93214429999999,
#     'accuracy': 10,
#     'velocity': 0,
#     'heading': 269,
#     'altitude': 319,
#     'verticalAccuracy': 48}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9351394, 35.9498738]},
#    'properties': {'timestampMs': '2020-02-11 14:23:25',
#     'latitudeE7': 35.9498738,
# ...
#     'latitudeE7': 35.953406,
#     'longitudeE7': -83.9395395,
#     'accuracy': 50,
#     'velocity': 2,
#     'heading': 48,
#     'altitude': 261,
#     'verticalAccuracy': 64}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9344455, 35.9559017]},
#    'properties': {'timestampMs': '2020-03-22 19:50:49',
#     'latitudeE7': 35.9559017,
#     'longitudeE7': -83.9344455,
#     'accuracy': 65,
#     'altitude': 277,
#     'verticalAccuracy': 10}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9296258, 35.9575831]},
#    'properties': {'timestampMs': '2020-03-22 19:53:14',
#     'latitudeE7': 35.9575831,
#     'longitudeE7': -83.9296258,
#     'accuracy': 65,
#     'altitude': 283,
#     'verticalAccuracy': 13}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.92195679999999, 35.9626708]},
#    'properties': {'timestampMs': '2020-03-22 19:56:52',
#     'latitudeE7': 35.9626708,
#     'longitudeE7': -83.92195679999999,
#     'accuracy': 65,
#     'altitude': 273,
#     'verticalAccuracy': 10}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.9177818, 35.961089799999996]},
#    'properties': {'timestampMs': '2020-03-22 19:59:55',
#     'latitudeE7': 35.961089799999996,
#     'longitudeE7': -83.9177818,
#     'accuracy': 30,
#     'velocity': 4,
#     'heading': 58,
#     'altitude': 279,
#     'verticalAccuracy': 32}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9101991, 35.963041]},
#    'properties': {'timestampMs': '2020-03-22 20:02:56',
#     'latitudeE7': 35.963041,
#     'longitudeE7': -83.9101991,
#     'accuracy': 10,
#     'velocity': 3,
#     'heading': 72,
#     'altitude': 280,
#     'verticalAccuracy': 12}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.90573909999999, 35.964962]},
#    'properties': {'timestampMs': '2020-03-22 20:05:57',
#     'latitudeE7': 35.964962,
#     'longitudeE7': -83.90573909999999,
#     'accuracy': 65,
#     'altitude': 271,
#     'verticalAccuracy': 10}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9058343, 35.9654089]},
#    'properties': {'timestampMs': '2020-03-23 05:59:57',
#     'latitudeE7': 35.9654089,
#     'longitudeE7': -83.9058343,
#     'accuracy': 65,
#     'altitude': 274,
#     'verticalAccuracy': 10}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.90578219999999, 35.965031599999996]},
#    'properties': {'timestampMs': '2020-03-25 00:06:59',
#     'latitudeE7': 35.965031599999996,
#     'longitudeE7': -83.90578219999999,
#     'accuracy': 65,
#     'altitude': 271,
#     'verticalAccuracy': 10}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9059322, 35.9652732]},
#    'properties': {'timestampMs': '2020-03-25 10:41:35',
#     'latitudeE7': 35.9652732,
#     'longitudeE7': -83.9059322,
#     'accuracy': 50,
#     'velocity': 0,
#     'altitude': 274,
#     'verticalAccuracy': 32}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9048978, 35.9641352]},
#    'properties': {'timestampMs': '2020-03-25 18:46:27',
#     'latitudeE7': 35.9641352,
#     'longitudeE7': -83.9048978,
#     'accuracy': 65,
#     'altitude': 255,
#     'verticalAccuracy': 10}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9015311, 35.9641234]},
#    'properties': {'timestampMs': '2020-03-25 18:49:43',
#     'latitudeE7': 35.9641234,
#     'longitudeE7': -83.9015311,
#     'accuracy': 30,
#     'velocity': 8,
#     'heading': 275,
#     'altitude': 252,
#     'verticalAccuracy': 16}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.91183339999999, 35.9609552]},
#    'properties': {'timestampMs': '2020-03-25 18:52:10',
#     'latitudeE7': 35.9609552,
#     'longitudeE7': -83.91183339999999,
#     'accuracy': 30,
#     'velocity': 7,
#     'heading': 245,
#     'altitude': 250,
#     'verticalAccuracy': 32}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.92255, 35.954367999999995]},
#    'properties': {'timestampMs': '2020-03-25 18:56:11',
#     'latitudeE7': 35.954367999999995,
#     'longitudeE7': -83.92255,
#     'accuracy': 100,
#     'velocity': 0,
#     'heading': 136,
#     'altitude': 249,
#     'verticalAccuracy': 48}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9265398, 35.9443956]},
#    'properties': {'timestampMs': '2020-03-25 19:00:27',
#     'latitudeE7': 35.9443956,
#     'longitudeE7': -83.9265398,
#     'accuracy': 76,
#     'altitude': 253,
#     'verticalAccuracy': 10}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9289927, 35.943889]},
#    'properties': {'timestampMs': '2020-03-25 19:02:32',
#     'latitudeE7': 35.943889,
#     'longitudeE7': -83.9289927,
#     'accuracy': 10,
#     'velocity': 0,
#     'heading': 233,
#     'altitude': 255,
#     'verticalAccuracy': 16}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.92703619999999, 35.944683]},
#    'properties': {'timestampMs': '2020-03-25 19:09:53',
#     'latitudeE7': 35.944683,
#     'longitudeE7': -83.92703619999999,
#     'accuracy': 50,
#     'velocity': 7,
#     'heading': 34,
#     'altitude': 253,
#     'verticalAccuracy': 6}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.924874, 35.953077199999996]},
#    'properties': {'timestampMs': '2020-03-25 19:13:37',
#     'latitudeE7': 35.953077199999996,
#     'longitudeE7': -83.924874,
#     'accuracy': 100,
#     'velocity': 3,
#     'heading': 11,
#     'altitude': 270,
#     'verticalAccuracy': 64}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.9264802, 35.958583399999995]},
#    'properties': {'timestampMs': '2020-03-25 19:16:38',
#     'latitudeE7': 35.958583399999995,
#     'longitudeE7': -83.9264802,
#     'accuracy': 100,
#     'velocity': 2,
#     'heading': 90,
#     'altitude': 265,
#     'verticalAccuracy': 96}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.920898, 35.9628995]},
#    'properties': {'timestampMs': '2020-03-25 19:20:49',
#     'latitudeE7': 35.9628995,
#     'longitudeE7': -83.920898,
#     'accuracy': 65,
#     'altitude': 278,
#     'verticalAccuracy': 10}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.9159246, 35.961424099999995]},
#    'properties': {'timestampMs': '2020-03-25 19:23:51',
#     'latitudeE7': 35.961424099999995,
#     'longitudeE7': -83.9159246,
#     'accuracy': 65,
#     'heading': 142,
#     'altitude': 273,
#     'verticalAccuracy': 10}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.9065998, 35.966100499999996]},
#    'properties': {'timestampMs': '2020-03-25 19:26:52',
#     'latitudeE7': 35.966100499999996,
#     'longitudeE7': -83.9065998,
#     'accuracy': 65,
#     'altitude': 280,
#     'verticalAccuracy': 10}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9057972, 35.9650034]},
#    'properties': {'timestampMs': '2020-03-25 19:31:41',
#     'latitudeE7': 35.9650034,
#     'longitudeE7': -83.9057972,
#     'accuracy': 65,
#     'altitude': 270,
#     'verticalAccuracy': 10}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.9059322, 35.965529499999995]},
#    'properties': {'timestampMs': '2020-03-26 11:49:29',
#     'latitudeE7': 35.965529499999995,
#     'longitudeE7': -83.9059322,
#     'accuracy': 65,
#     'altitude': 275,
#     'verticalAccuracy': 10}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9057394, 35.9649675]},
#    'properties': {'timestampMs': '2020-03-26 13:11:12',
#     'latitudeE7': 35.9649675,
#     'longitudeE7': -83.9057394,
#     'accuracy': 65,
#     'altitude': 269,
#     'verticalAccuracy': 10}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.90639499999999, 35.964067799999995]},
#    'properties': {'timestampMs': '2020-03-26 16:18:41',
#     'latitudeE7': 35.964067799999995,
#     'longitudeE7': -83.90639499999999,
#     'accuracy': 30,
#     'velocity': 3,
#     'heading': 185,
#     'altitude': 262,
#     'verticalAccuracy': 64}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.89712829999999, 35.9650184]},
#    'properties': {'timestampMs': '2020-03-26 16:24:26',
#     'latitudeE7': 35.9650184,
#     'longitudeE7': -83.89712829999999,
#     'accuracy': 65,
#     'altitude': 255,
#     'verticalAccuracy': 10}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.91295219999999, 35.9609612]},
#    'properties': {'timestampMs': '2020-03-26 16:28:30',
#     'latitudeE7': 35.9609612,
#     'longitudeE7': -83.91295219999999,
#     'accuracy': 65,
#     'altitude': 254,
#     'verticalAccuracy': 10}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9210684, 35.9569517]},
#    'properties': {'timestampMs': '2020-03-26 16:30:52',
#     'latitudeE7': 35.9569517,
#     'longitudeE7': -83.9210684,
#     'accuracy': 65,
#     'heading': 226,
#     'altitude': 278,
#     'verticalAccuracy': 11}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9246386, 35.950756]},
#    'properties': {'timestampMs': '2020-03-26 16:33:09',
#     'latitudeE7': 35.950756,
#     'longitudeE7': -83.9246386,
#     'accuracy': 30,
#     'velocity': 3,
#     'heading': 180,
#     'altitude': 321,
#     'verticalAccuracy': 24}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9375882, 35.9432158]},
#    'properties': {'timestampMs': '2020-03-26 16:39:21',
#     'latitudeE7': 35.9432158,
#     'longitudeE7': -83.9375882,
#     'accuracy': 10,
#     'velocity': 0,
#     'heading': 197,
#     'altitude': 253,
#     'verticalAccuracy': 32}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.93521009999999, 35.9433418]},
#    'properties': {'timestampMs': '2020-03-26 16:42:31',
#     'latitudeE7': 35.9433418,
#     'longitudeE7': -83.93521009999999,
#     'accuracy': 5,
#     'velocity': 4,
#     'heading': 111,
#     'altitude': 235,
#     'verticalAccuracy': 12}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9284536, 35.9439971]},
#    'properties': {'timestampMs': '2020-03-26 16:45:11',
#     'latitudeE7': 35.9439971,
#     'longitudeE7': -83.9284536,
#     'accuracy': 50,
#     'velocity': 4,
#     'heading': 62,
#     'altitude': 247,
#     'verticalAccuracy': 48}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.92647029999999, 35.9455588]},
#    'properties': {'timestampMs': '2020-03-26 16:47:11',
#     'latitudeE7': 35.9455588,
#     'longitudeE7': -83.92647029999999,
#     'accuracy': 10,
#     'velocity': 0,
#     'heading': 235,
#     'altitude': 253,
#     'verticalAccuracy': 16}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9249023, 35.9500836]},
#    'properties': {'timestampMs': '2020-03-26 16:54:44',
#     'latitudeE7': 35.9500836,
#     'longitudeE7': -83.9249023,
#     'accuracy': 10,
#     'velocity': 1,
#     'heading': 36,
#     'altitude': 274,
#     'verticalAccuracy': 24}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.9233, 35.953763099999996]},
#    'properties': {'timestampMs': '2020-03-26 16:59:33',
#     'latitudeE7': 35.953763099999996,
#     'longitudeE7': -83.9233,
#     'accuracy': 5,
#     'velocity': 1,
#     'heading': 13,
#     'altitude': 250,
#     'verticalAccuracy': 8}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.92111009999999, 35.9567255]},
#    'properties': {'timestampMs': '2020-03-26 17:04:31',
#     'latitudeE7': 35.9567255,
#     'longitudeE7': -83.92111009999999,
#     'accuracy': 10,
#     'velocity': 1,
#     'heading': 83,
#     'altitude': 230,
#     'verticalAccuracy': 32}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.91860989999999, 35.958127999999995]},
#    'properties': {'timestampMs': '2020-03-26 17:08:42',
#     'latitudeE7': 35.958127999999995,
#     'longitudeE7': -83.91860989999999,
#     'accuracy': 10,
#     'velocity': 0,
#     'heading': 117,
#     'altitude': 249,
#     'verticalAccuracy': 12}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9155158, 35.9595821]},
#    'properties': {'timestampMs': '2020-03-26 17:12:13',
#     'latitudeE7': 35.9595821,
#     'longitudeE7': -83.9155158,
#     'accuracy': 50,
#     'velocity': 2,
#     'heading': 64,
#     'altitude': 225,
#     'verticalAccuracy': 64}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9125644, 35.9607799]},
#    'properties': {'timestampMs': '2020-03-26 17:15:21',
#     'latitudeE7': 35.9607799,
#     'longitudeE7': -83.9125644,
#     'accuracy': 30,
#     'velocity': 1,
#     'heading': 125,
#     'altitude': 238,
#     'verticalAccuracy': 32}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.91005729999999, 35.9621935]},
#    'properties': {'timestampMs': '2020-03-26 17:18:27',
#     'latitudeE7': 35.9621935,
#     'longitudeE7': -83.91005729999999,
#     'accuracy': 65,
#     'altitude': 258,
#     'verticalAccuracy': 10}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9068492, 35.9638553]},
#    'properties': {'timestampMs': '2020-03-26 17:22:23',
#     'latitudeE7': 35.9638553,
#     'longitudeE7': -83.9068492,
#     'accuracy': 50,
#     'velocity': 1,
#     'heading': 93,
#     'altitude': 258,
#     'verticalAccuracy': 48}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9050525, 35.9644575]},
#    'properties': {'timestampMs': '2020-03-26 17:25:04',
#     'latitudeE7': 35.9644575,
#     'longitudeE7': -83.9050525,
#     'accuracy': 65,
#     'altitude': 258,
#     'verticalAccuracy': 10}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.9058261, 35.965106899999995]},
#    'properties': {'timestampMs': '2020-03-27 11:29:11',
#     'latitudeE7': 35.965106899999995,
#     'longitudeE7': -83.9058261,
#     'accuracy': 65,
#     'altitude': 271,
#     'verticalAccuracy': 10}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9087651, 35.963583]},
#    'properties': {'timestampMs': '2020-03-27 19:29:03',
#     'latitudeE7': 35.963583,
#     'longitudeE7': -83.9087651,
#     'accuracy': 10,
#     'velocity': 5,
#     'heading': 240,
#     'altitude': 281,
#     'verticalAccuracy': 24}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.915613, 35.9593656]},
#    'properties': {'timestampMs': '2020-03-27 19:32:03',
#     'latitudeE7': 35.9593656,
#     'longitudeE7': -83.915613,
#     'accuracy': 50,
#     'velocity': 4,
#     'heading': 233,
#     'altitude': 259,
#     'verticalAccuracy': 32}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9221735, 35.9558706]},
#    'properties': {'timestampMs': '2020-03-27 19:34:33',
#     'latitudeE7': 35.9558706,
#     'longitudeE7': -83.9221735,
#     'accuracy': 65,
#     'altitude': 253,
#     'verticalAccuracy': 10}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9227575, 35.945558]},
#    'properties': {'timestampMs': '2020-03-27 19:38:29',
#     'latitudeE7': 35.945558,
#     'longitudeE7': -83.9227575,
#     'accuracy': 65,
#     'altitude': 255,
#     'verticalAccuracy': 10}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9259402, 35.9432738]},
#    'properties': {'timestampMs': '2020-03-27 19:44:30',
#     'latitudeE7': 35.9432738,
#     'longitudeE7': -83.9259402,
#     'accuracy': 65,
#     'altitude': 250,
#     'verticalAccuracy': 10}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.9273572, 35.9512576]},
#    'properties': {'timestampMs': '2020-03-27 19:47:35',
#     'latitudeE7': 35.9512576,
#     'longitudeE7': -83.9273572,
#     'accuracy': 65,
#     'heading': 320,
#     'altitude': 271,
#     'verticalAccuracy': 10}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.926859, 35.9552662]},
#    'properties': {'timestampMs': '2020-03-27 19:50:05',
#     'latitudeE7': 35.9552662,
#     'longitudeE7': -83.926859,
#     'accuracy': 65,
#     'altitude': 271,
#     'verticalAccuracy': 10}},
#   ...]}
